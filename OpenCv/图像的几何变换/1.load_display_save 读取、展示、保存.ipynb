# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread('image.jpg')#读取图片

# %%
plt.imshow(image)
plt.axis('off')#去掉坐标
plt.show()

# %%
cv2.imshow('img',image)#展示图片
cv2.waitKey(0)#等待时间,0：不关闭 非0：表示等待关闭的时间 单位为ms
cv2.destroyAllWindows()#关闭所有窗口

# %%
import cv2

# %%
image=cv2.imread('image.jpg')

# %%
cv2.imshow('ming',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#JPG : 0 压缩比高 100 压缩比低
#PNG : 0 压缩比低 9  压缩比高

# %%
import cv2
image=cv2.imread('image.jpg',1)
cv2.imwrite('image100.jpg',image,[cv2.IMWRITE_JPEG_QUALITY,100])
# Out:
# True

# %%
import cv2
image=cv2.imread('image.jpg',1)
cv2.imwrite('image50.jpg',image,[cv2.IMWRITE_JPEG_QUALITY,50])
#数字取值在0-100之间 不同的数字代表的图像质量不同
#数字越大 图像质量越好 所占空间越大
# Out:
# True

# %%
import cv2
image=cv2.imread('image.jpg',1)
cv2.imwrite('image5.png',image,[cv2.IMWRITE_PNG_COMPRESSION,5])
# Out:
# True

# %%
import cv2
image=cv2.imread('image.jpg',1)
cv2.imwrite('image0.png',image,[cv2.IMWRITE_PNG_COMPRESSION,0])
# Out:
# True

# %%
import cv2
image=cv2.imread('image.jpg',1)
cv2.imwrite('image9.png',image,[cv2.IMWRITE_PNG_COMPRESSION,9])
#数字取值在0-9之间 不同的数字代表的图像质量不同
#数字越小 图像质量越好 所占空间越大
# Out:
# True

# %%
import cv2
img=cv2.imread('image.jpg')
(b,g,r)=img[100,90]
print(b,g,r)
#用for循环对像素进行操作
for i in range(1,200):
    img[100,10+i]=(0,0,255)#红色的横线
    img[10+i,200]=(255,0,0)#蓝色的竖线
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 207 215 208

# %%
import cv2
img=cv2.imread('image.jpg')
(b,g,r)=img[1000,550]
print(b,g,r)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 59 43 36
