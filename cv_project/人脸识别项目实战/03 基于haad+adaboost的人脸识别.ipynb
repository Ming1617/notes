# %%
import cv2
import numpy as np
face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
eye_xml=cv2.CascadeClassifier('haarcascade_eye.xml')
nons_xml=cv2.CascadeClassifier('haarcascade_mcs_nose.xml')
#load jpg
img=cv2.imread('img.png')
cv2.imshow('src',img)
# haar gray
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# detect faces 1 data 2 scale 3 
faces=face_xml.detectMultiScale(gray,1.2,2)
print('face=',len(faces))
#draw
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_face=gray[y:y+h,x:x+w]
    roi_color=img[y:y+h,x:x+w]
    
    #1 gray
    eyes=eye_xml.detectMultiScale(roi_face)
    print('eye=',len(eyes))
    for (e_x,e_y,e_w,e_h) in eyes:
        cv2.rectangle(roi_color,(e_x,e_y),(e_x+e_w,e_y+e_h),(255,0,0),0)
cv2.imshow('dst',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# face= 9
# eye= 0
# eye= 0
# eye= 0
# eye= 0
# eye= 0
# eye= 0
# eye= 0
# eye= 0
# eye= 0

# %%
#图片检测脸鼻子，眼
import cv2
import numpy as np
face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
eye_xml=cv2.CascadeClassifier('haarcascade_eye.xml')
nose_xml=cv2.CascadeClassifier('haarcascade_mcs_nose.xml')
#load jpg
img=cv2.imread('face.png')
# cv2.imshow('src',img)
# haar gray
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# detect faces 1 data 2 scale 3 
faces=face_xml.detectMultiScale(gray,1.2,3)
print('face=',len(faces))
#draw
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_face=gray[y:y+h,x:x+w]
    roi_color=img[y:y+h,x:x+w]
    
    #1 gray
    eyes=eye_xml.detectMultiScale(roi_face,1.4,4)
    print('eye=',len(eyes))
    for (e_x,e_y,e_w,e_h) in eyes:
        cv2.rectangle(roi_color,(e_x,e_y),(e_x+e_w,e_y+e_h),(0,0,255),0)
    noses=nose_xml.detectMultiScale(roi_face,1.4,4)
    print('noses=',len(noses))
    for (n_x,n_y,n_w,n_h) in noses:
        cv2.rectangle(roi_color,(n_x,n_y),(n_x+n_w,n_y+n_h),(0,255,0),0)
    
cv2.imshow('dst',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# face= 1
# eye= 2
# noses= 1

# %%
#视频检测人脸,
#视频分解图片
#l load 2 info 3 parse 4 imshow imwrite
import cv2
import os
import matplotlib.pyplot as plt
cap=cv2.VideoCapture('face_train.mp4')
isOpened=cap.isOpened
print(isOpened)
fps=cap.get(cv2.CAP_PROP_FPS)
width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(fps,width,height)
i=0
n=0
while(isOpened):
    if i==20:
        break;
    else:
        i=i+1
    (flag,frame)=cap.read()
    face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
    eye_xml=cv2.CascadeClassifier('haarcascade_eye.xml')
    nose_xml=cv2.CascadeClassifier('haarcascade_mcs_nose.xml')
    #load jpg
    img=frame
    # cv2.imshow('src',img)
    # haar gray
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # detect faces 1 data 2 scale 3 
    faces=face_xml.detectMultiScale(gray,1.2,2)
    print('face=',len(faces))
    #draw
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_face=gray[y:y+h,x:x+w]
        roi_color=img[y:y+h,x:x+w]

        #1 gray
        eyes=eye_xml.detectMultiScale(roi_face)
        print('eye=',len(eyes))
        for (e_x,e_y,e_w,e_h) in eyes:
            cv2.rectangle(roi_color,(e_x,e_y),(e_x+e_w,e_y+e_h),(255,0,0),0)
        noses=nose_xml.detectMultiScale(roi_face,1.4,4)
        print('noses=',len(noses))
        for (n_x,n_y,n_w,n_h) in noses:
            cv2.rectangle(roi_color,(n_x,n_y),(n_x+n_w,n_y+n_h),(0,255,0),0)
    path='face_test.mp4'
#     print(os.path.exists(path))
    if not(os.path.exists(path)):
        print(1)
        imgInfo=img.shape
        heigth=imgInfo[0]
        width=imgInfo[1]
        size=(imgInfo[1],imgInfo[0])
        print('size:',size)
        VideoWrite=cv2.VideoWriter(path,-1,5,size)
    n=n+1
#     cv2.imshow('img'+str(n),img)
    print(n)
    VideoWrite.write(img)
print('end!')
# Out:
# <built-in method isOpened of cv2.VideoCapture object at 0x0000020E31DF2950>
# 8.947368421052632 1364 724
# face= 1
# eye= 2
# noses= 0
# 1
# size: (1364, 724)
# 1
# face= 1
# eye= 2
# noses= 0
# 2
# face= 1
# eye= 2
# noses= 1
# 3
# face= 1
# eye= 2
# noses= 0
# 4
# face= 1
# eye= 2
# noses= 0
# 5
# face= 1
# eye= 2
# noses= 1
# 6
# face= 1
# eye= 2
# noses= 1
# 7
# face= 1
# eye= 2
# noses= 1
# 8
# face= 1
# eye= 2
# noses= 1
# 9
# face= 1
# eye= 2
# noses= 1
# 10
# face= 1
# eye= 2
# noses= 1
# 11
# face= 1
# eye= 3
# noses= 0
# 12
# face= 1
# eye= 2
# noses= 1
# 13
# face= 1
# eye= 2
# noses= 0
# 14
# face= 1
# eye= 2
# noses= 0
# 15
# face= 1
# eye= 2
# noses= 0
# 16
# face= 1
# eye= 2
# noses= 0
# 17
# face= 1
# eye= 2
# noses= 0
# 18
# face= 1
# eye= 2
# noses= 0
# 19
# face= 1
# eye= 2
# noses= 0
# 20
# end!

# %%
#打开摄像头检测
import numpy as np
import cv2
import os
cap=cv2.VideoCapture(0)
codec=cv2.VideoWriter_fourcc(*'MJPG')#指定编码器
fps=20.0
frameSize=(640,480)
out=cv2.VideoWriter('video.avi',codec,fps,frameSize)
path='video.avi'
print('按q-结束视频录制')
while(cap.isOpened()):
    ret,frame=cap.read()
    
    if ret==True:
        face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
        eye_xml=cv2.CascadeClassifier('haarcascade_eye.xml')
        #load jpg
        img=frame
        # cv2.imshow('src',img)
        # haar gray
        gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        # detect faces 1 data 2 scale 3 
        faces=face_xml.detectMultiScale(gray,1.2,2)
        print('face=',len(faces))
        #draw
        for (x,y,w,h) in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_face=gray[y:y+h,x:x+w]
            roi_color=img[y:y+h,x:x+w]

            #1 gray
            eyes=eye_xml.detectMultiScale(roi_face)
            print('eye=',len(eyes))
            for (e_x,e_y,e_w,e_h) in eyes:
                cv2.rectangle(roi_color,(e_x,e_y),(e_x+e_w,e_y+e_h),(255,0,0),0)
        cv2.imshow('frame',frame)
        out.write(frame)
        if cv2.waitKey(1)==ord('s'):
            # print(os.listdir(os.getcwd()))
            break
        elif cv2.waitKey(1)==ord('q'):
            cap.release()
            out.release()
            
            # print(os.listdir(os.getcwd()))
            if os.path.exists(path):
                os.remove(path)
                break
            break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 按q-结束视频录制
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 1
# face= 1
# eye= 0
# face= 0
# face= 1
# eye= 1
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 0
# face= 1
# eye= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 0
# face= 1
# eye= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0
# face= 1
# eye= 0

# %%
#视频检测人脸并加入马赛克
#视频分解图片
#l load 2 info 3 parse 4 imshow imwrite
def masaike(img,x_b,y_b,x_e,y_e,n):#b:开始，e:结束
    import cv2
    import random
    for i in range(int(y_b),int(y_e),int(n)):#100
        for j in range(x_b,x_e,n):#200
            x1=int(random.random()*n-1)
            y1=int(random.random()*n-1)
    #         print(b,g,r)
            for ii in range(i,i+n):
                for jj in range(j,j+n):
                    img[ii,jj]=img[i+x1,j+y1]
    return img
import cv2
import os
import matplotlib.pyplot as plt
cap=cv2.VideoCapture('face_train.mp4')
isOpened=cap.isOpened
print(isOpened)
fps=cap.get(cv2.CAP_PROP_FPS)
width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(fps,width,height)
i=0
n=0
while(isOpened):
    if i==20:
        break;
    else:
        i=i+1
    (flag,frame)=cap.read()
    face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
    #load jpg
    img=frame
    # cv2.imshow('src',img)
    # haar gray
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # detect faces 1 data 2 scale 3 
    faces=face_xml.detectMultiScale(gray,1.2,2)
    print('face=',len(faces))
    #draw
    for (x,y,w,h) in faces:
        img=masaike(img,x,y,x+w,y+h,10)#马赛克函数

        #1 gray
    path='face_test_masaike.mp4'
#     print(os.path.exists(path))
    if not(os.path.exists(path)):
        print(1)
        imgInfo=img.shape
        heigth=imgInfo[0]
        width=imgInfo[1]
        size=(imgInfo[1],imgInfo[0])
        print('size:',size)
        VideoWrite=cv2.VideoWriter(path,-1,5,size)
    n=n+1
#     cv2.imshow('img'+str(n),img)
    print(n)
    VideoWrite.write(img)
print('end!')
# Out:
# <built-in method isOpened of cv2.VideoCapture object at 0x000001A43296DE10>
# 8.947368421052632 1364 724
# face= 1
# 1
# size: (1364, 724)
# 1
# face= 1
# 2
# face= 1
# 3
# face= 1
# 4
# face= 1
# 5
# face= 1
# 6
# face= 1
# 7
# face= 1
# 8
# face= 1
# 9
# face= 1
# 10
# face= 1
# 11
# face= 1
# 12
# face= 1
# 13
# face= 1
# 14
# face= 1
# 15
# face= 1
# 16
# face= 1
# 17
# face= 1
# 18
# face= 1
# 19
# face= 1
# 20
# end!

# %%
#打开摄像头检测并添加马赛克
import numpy as np
import cv2
import os
def masaike(img,x_b,y_b,x_e,y_e,n):#b:开始，e:结束
    import cv2
    import random
    for i in range(int(y_b),int(y_e),int(n)):#100
        for j in range(x_b,x_e,n):#200
            x1=int(random.random()*n-1)
            y1=int(random.random()*n-1)
    #         print(b,g,r)
            for ii in range(i,i+n):
                for jj in range(j,j+n):
                    img[ii,jj]=img[i+x1,j+y1]
    return img
cap=cv2.VideoCapture(0)
codec=cv2.VideoWriter_fourcc(*'MJPG')#指定编码器
fps=20.0
frameSize=(640,480)
out=cv2.VideoWriter('video.avi',codec,fps,frameSize)
path='video.avi'
print('按q-结束视频录制')
while(cap.isOpened()):
    ret,frame=cap.read()
    
    if ret==True:
        face_xml=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
        eye_xml=cv2.CascadeClassifier('haarcascade_eye.xml')
        #load jpg
        img=frame
        # cv2.imshow('src',img)
        # haar gray
        gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        # detect faces 1 data 2 scale 3 
        faces=face_xml.detectMultiScale(gray,1.2,2)
        print('face=',len(faces))
        #draw
        for (x,y,w,h) in faces:
            img=masaike(img,x,y,x+w,y+h,10)#马赛克函数

        cv2.imshow('frame',frame)
        out.write(frame)
        if cv2.waitKey(1)==ord('s'):
            # print(os.listdir(os.getcwd()))
            break
        elif cv2.waitKey(1)==ord('q'):
            cap.release()
            out.release()
            
            # print(os.listdir(os.getcwd()))
            if os.path.exists(path):
                os.remove(path)
                break
            break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 按q-结束视频录制
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# face= 1
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
# face= 1
# face= 0
# face= 0
# face= 0
# face= 0
# face= 0
